# %% [markdown]
# <a href="https://colab.research.google.com/github/hasratb/ASL_Classification/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/val/T/T645.jpg
#   inflating: data/val/T/T646.jpg
#   inflating: data/val/T/T647.jpg
#   inflating: data/val/T/T648.jpg
#   inflating: data/val/T/T649.jpg
#   inflating: data/val/T/T65.jpg
#   inflating: data/val/T/T650.jpg
#   inflating: data/val/T/T651.jpg
#   inflating: data/val/T/T652.jpg
#   inflating: data/val/T/T653.jpg
#   inflating: data/val/T/T654.jpg
#   inflating: data/val/T/T655.jpg
#   inflating: data/val/T/T656.jpg
#   inflating: data/val/T/T657.jpg
#   inflating: data/val/T/T658.jpg
#   inflating: data/val/T/T659.jpg
#   inflating: data/val/T/T66.jpg
#   inflating: data/val/T/T660.jpg
#   inflating: data/val/T/T661.jpg
#   inflating: data/val/T/T662.jpg
#   inflating: data/val/T/T663.jpg
#   inflating: data/val/T/T664.jpg
#   inflating: data/val/T/T665.jpg
#   inflating: data/val/T/T666.jpg
#   inflating: data/val/T/T667.jpg
#   inflating: data/val/T/T668.jpg
#   inflating: data/val/T/T669.jpg
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/yolo11x-cls.pt')

model.train(data='data', epochs=15)
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r data.zip /content/runs
# Out:
# updating: content/runs/ (stored 0%)
# updating: content/runs/classify/ (stored 0%)
# updating: content/runs/classify/train/ (stored 0%)
# updating: content/runs/classify/train/train_batch1626.jpg (deflated 8%)
# updating: content/runs/classify/train/val_batch1_labels.jpg (deflated 7%)
# updating: content/runs/classify/train/events.out.tfevents.1730949764.3c3f7e92dc4c.320.0 (deflated 94%)
# updating: content/runs/classify/train/val_batch1_pred.jpg (deflated 7%)
# updating: content/runs/classify/train/weights/ (stored 0%)
# updating: content/runs/classify/train/weights/best.pt (deflated 8%)
# updating: content/runs/classify/train/weights/last.pt (deflated 8%)
# updating: content/runs/classify/train/train_batch1.jpg (deflated 8%)
# updating: content/runs/classify/train/train_batch1627.jpg (deflated 7%)
# updating: content/runs/classify/train/args.yaml (deflated 52%)
# updating: content/runs/classify/train/confusion_matrix_normalized.png (deflated 17%)
# ...

# %%
from google.colab import files
files.download('data.zip')

# %%
from google.colab import files
files.download('/content/data/train.cache')
files.download('/content/data/val.cache')

# %%
model= YOLO('runs/classify/train/weights/best.pt')
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11x-cls summary (fused): 227 layers, 28,365,722 parameters, 0 gradients, 110.4 GFLOPs
# train: /content/data/train... found 5200 images in 26 classes ✅
# val: /content/data/val... found 20800 images in 26 classes ✅
# test: None...
# val: Scanning /content/data/val... 20800 images, 0 corrupt: 100%|██████████| 20800/20800 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/data/val/A/A799.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/B/B799.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/C/C799.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/D/D799.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/E/E799.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/F/F799.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/G/G799.jpg: corrupt JPEG restored and saved
# ...

# %%
results=model('/content/F-41.jpg', save=True)
#results
for r in results:
    print(r.probs)
# Out:
# image 1/1 /content/F-41.jpg: 224x224 F 0.34, B 0.17, X 0.12, T 0.10, I 0.09, 15.0ms
# Speed: 6.4ms preprocess, 15.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([0.0617, 0.1688, 0.0015, 0.0285, 0.0098, 0.3384, 0.0032, 0.0008, 0.0924, 0.0017, 0.0071, 0.0026, 0.0136, 0.0049, 0.0009, 0.0005, 0.0004, 0.0099, 0.0143, 0.1005, 0.0037, 0.0084, 0.0067, 0.1161, 0.0028, 0.0011], device='cuda:0')
# orig_shape: None
# shape: torch.Size([26])
# top1: 5
# top1conf: tensor(0.3384, device='cuda:0')
# top5: [5, 1, 23, 19, 8]
# top5conf: tensor([0.3384, 0.1688, 0.1161, 0.1005, 0.0924], device='cuda:0')
